# %% [markdown]
# **Statistics Advanced - 1| Assignment**
#
# Question 1: What is a random variable in probability theory?
#
# Answer:
# A random variable is a numerical quantity whose value depends on the outcome of a random experiment. Instead of describing outcomes in words (like “heads” or “tails”), random variables assign numbers to those outcomes.
#
# Example: If you flip a coin, you can define a random variable X such that X = 1 for heads and X = 0 for tails.
#
# Question 2: What are the types of random variables?
#
# Answer:
# There are two main types of random variables:
#
# Discrete Random Variable – Takes only a finite or countably infinite number of distinct values. Example: Number of students present in a class.
#
# Continuous Random Variable – Takes values from an interval of real numbers, and the possible outcomes cannot be listed individually. Example: Height of a person (which can be 160.5 cm, 160.55 cm, etc.).
#
# Question 3: Explain the difference between discrete and continuous distributions.
#
# Answer:
#
# Discrete Distribution:
#
# Associated with discrete random variables.
#
# Probabilities are assigned to specific values.
#
# Represented by a probability mass function (PMF).
#
# Example: Binomial distribution, Poisson distribution.
#
# Continuous Distribution:
#
# Associated with continuous random variables.
#
# Probabilities are assigned over intervals, not individual points.
#
# Represented by a probability density function (PDF).
#
# Example: Normal distribution, Exponential distribution.
#
# Question 4: What is a binomial distribution, and how is it used in probability?
#
# Answer:
# The binomial distribution is a discrete probability distribution that models the number of “successes” in a fixed number of independent trials, where each trial has only two possible outcomes (success or failure) and the probability of success remains constant.
#
# Formula:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# (
# 𝑛
# 𝑘
# )
# 𝑝
# 𝑘
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘
# P(X=k)=(
# k
# n
# 	​
#
# )p
# k
# (1−p)
# n−k
#
# Where:
#
# 𝑛
# n = number of trials
#
# 𝑘
# k = number of successes
#
# 𝑝
# p = probability of success on each trial
#
# Examples of use:
#
# Tossing a coin multiple times and counting heads.
#
# Quality control: number of defective items in a batch.
#
# Survey results: number of people agreeing to a question.
#
# Question 5: What is the standard normal distribution, and why is it important?
#
# Answer:
# The standard normal distribution is a special case of the normal distribution with a mean (μ) = 0 and a standard deviation (σ) = 1. It is represented by the bell-shaped curve centered at zero.
#
# Importance:
#
# It allows us to convert any normal distribution into a standard form using the z-score formula:
# P(X=k)=(kn​)pk(1−p)n−k	​
#
# Probability tables (Z-tables) are based on the standard normal distribution, making it a tool for hypothesis testing, confidence intervals, and statistical inference.
#
# Many real-world phenomena approximate a normal distribution (heights, test scores, measurement errors).
#
# Question 6: What is the Central Limit Theorem (CLT), and why is it critical in statistics?
#
# Answer:
# The Central Limit Theorem (CLT) states that when independent random samples are taken from any population with a finite mean and variance, the sampling distribution of the sample mean will approach a normal distribution as the sample size becomes large, regardless of the original population’s distribution.
#
# Formula (approximate distribution):
#
# Xˉ∼N(μ,nσ2​)as n→∞
#
# Why it is critical:
#
# It justifies the widespread use of the normal distribution in statistics.
#
# Enables reliable use of hypothesis testing and confidence intervals.
#
# Provides a foundation for probability-based decision making in fields like quality control, finance, and research.
#
# Question 7: What is the significance of confidence intervals in statistical analysis?
#
# Answer:
# A confidence interval (CI) is a range of values, derived from sample data, that is likely to contain the true population parameter (like mean or proportion) with a specified level of confidence (e.g., 95%).
#
# Significance:
#
# Provides an estimate of uncertainty around sample statistics.
#
# Helps in decision-making by showing the reliability of the results.
#
# Narrower intervals → more precise estimates; wider intervals → less precise.
#
# Commonly used in hypothesis testing and reporting research findings.
#
#  Example: If the 95% CI for average height = [165, 175] cm, it means we are 95% confident that the true population mean lies within this range.
#
# Question 8: What is the concept of expected value in a probability distribution?
#
# Answer:
# The expected value (EV) is the long-run average value of a random variable after many repetitions of the same experiment. It represents the "center of gravity" of the probability distribution.
#
# Formula:
# For discrete random variable X:
# E[X]=∑xi​⋅P(xi​)
#
# For continuous random variable X:
# E[X]=∫−∞∞​x⋅f(x)dx
#
# Example: If you roll a fair six-sided die:
# E[X]=61+2+3+4+5+6​=3.5
#
# This means on average, the die roll outcome tends toward 3.5 in the long run.

# %%
#Question 9: Write a Python program to generate 1000 random numbers from a normal distribution with mean = 50 and standard deviation = 5. Compute its mean and standard deviation using NumPy, and draw a histogram to visualize the distribution.


#Answer:

import numpy as np
import matplotlib.pyplot as plt

# Generate 1000 random numbers from a normal distribution (mean=50, std=5)
data = np.random.normal(loc=50, scale=5, size=1000)

# Compute mean and standard deviation
mean = np.mean(data)
std_dev = np.std(data)

print("Sample Mean:", mean)
print("Sample Standard Deviation:", std_dev)

# Draw histogram
plt.hist(data, bins=30, color='skyblue', edgecolor='black', density=True)
plt.title("Histogram of Normally Distributed Data (mean=50, std=5)")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()
# Out:
# Sample Mean: 50.268886393718084
# Sample Standard Deviation: 4.9118206514252485

# %% [markdown]
# #Question 10: You are working as a data analyst for a retail company. The company has
# collected daily sales data for 2 years and wants you to identify the overall sales trend.
#
# Answer
#
# 📌 Conceptual Explanation
#
# You are asked to estimate the average daily sales using the Central Limit Theorem (CLT).
#
# The CLT says: if we take repeated random samples from a population, the distribution of the sample means will approximate a normal distribution, even if the original data is not perfectly normal.
#
# Since we have daily sales data, we can:
#
# Compute the sample mean (xˉ).
#
# Compute the sample standard deviation (s).
#
# Use the CLT to approximate a 95% confidence interval (CI) for the true mean daily sales.
#
# The formula for a confidence interval:
# ˉ±Zα/2​⋅n
# ​s​
# xˉ±Zα/2​⋅n
# ​s​
# 	​
# Where:
#
# 𝑥
# ˉ
# x
# ˉ
#  = sample mean
#
# 𝑠
# s = sample standard deviation
#
# 𝑛
# n = sample size
#
# 𝑍
# 𝛼
# /
# 2
# Z
# α/2
# 	​
#
#  = 1.96 for 95% confidence

# %%
import numpy as np
import scipy.stats as st

# Daily sales data (sample)
daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255,
               235, 260, 245, 250, 225, 270, 265, 255, 250, 260]

# Convert to NumPy array
data = np.array(daily_sales)

# Sample size, mean, and standard deviation
n = len(data)
mean = np.mean(data)
std_dev = np.std(data, ddof=1)  # use ddof=1 for sample std

# 95% confidence interval using CLT (Z-distribution)
confidence_level = 0.95
alpha = 1 - confidence_level
z_critical = st.norm.ppf(1 - alpha/2)  # 1.96 for 95%

# Margin of error
margin_of_error = z_critical * (std_dev / np.sqrt(n))

# Confidence interval
ci_lower = mean - margin_of_error
ci_upper = mean + margin_of_error

print("Sample Mean:", mean)
print("Sample Standard Deviation:", std_dev)
print(f"95% Confidence Interval for Mean: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# Sample Mean: 248.25
# Sample Standard Deviation: 17.26534405284638
# 95% Confidence Interval for Mean: (240.68, 255.82)
